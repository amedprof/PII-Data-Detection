# %%
cd ../src
# Out:
# /workspace/Script/NLP/PII/src

# %%
import os
import gc
import sys
import json
import time
import torch
import joblib
import random
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from pathlib import Path
import plotly.express as px
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: '%.4f' % x)

# %%
import re
import os
import gc
import math
import time
import json
import random
import numpy as np
import pandas as pd
import wandb

from pathlib import Path

import torch 
import torch.nn as nn
from torch.cuda import amp
import torch.optim as optim
import torch.nn.functional as F

from transformers import AutoTokenizer, AutoModel, AutoConfig
 
from data.data_utils import to_gpu,to_np
from data.dataset import FeedbackDataset,CustomCollator
from torch.utils.data import DataLoader

from model_zoo.models import FeedbackModel,span_nms,aggregate_tokens_to_words
from metrics_loss.metrics import score_feedback,score,pii_fbeta_score_v2,compute_metrics
from transformers import get_linear_schedule_with_warmup,get_cosine_schedule_with_warmup,get_polynomial_decay_schedule_with_warmup,get_cosine_with_hard_restarts_schedule_with_warmup

from sklearn.metrics import log_loss 
from tqdm.auto import tqdm

from utils.utils import count_parameters
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
# pip install deepspeed

# %%
from tqdm.auto import tqdm
import re
from difflib import SequenceMatcher

import codecs
import os
from collections import Counter
from typing import Dict, List, Tuple

from tqdm.auto import tqdm
import numpy as np
import pandas as pd
from text_unidecode import unidecode
import joblib
import torch

# ======================================================================================== #
def get_text_start_end(txt, s, search_from=0):
    txt = txt[int(search_from):]
    try:
        idx = txt.find(s)
        if idx >= 0:
            st = idx
            ed = st + len(s)
        else:
            raise ValueError('Error')
    except:
        res = [(m.start(0), m.end(0)) for m in re.finditer(s, txt)]
        if len(res):
            st, ed = res[0][0], res[0][1]
        else:
            m = SequenceMatcher(None, s, txt).get_opcodes()
            for tag, i1, i2, j1, j2 in m:
                if tag == 'replace':
                    s = s[:i1] + txt[j1:j2] + s[i2:]
                if tag == "delete":
                    s = s[:i1] + s[i2:]

            res = [(m.start(0), m.end(0)) for m in re.finditer(s, txt)]
            if len(res):
                st, ed = res[0][0], res[0][1]
            else:
                idx = txt.find(s)
                if idx >= 0:
                    st = idx
                    ed = st + len(s)
                else:
                    st, ed = 0, 0
    return st + search_from, ed + search_from
    
def get_offset_mapping(full_text, tokens):
    offset_mapping = []

    current_offset = 0
    for token in tokens:
        start, end = get_text_start_end(full_text, token, search_from=current_offset)
        offset_mapping.append((start, end))
        current_offset = end

    return offset_mapping


import spacy
from spacy import displacy
from pylab import cm, matplotlib
import os

colors = {
            'NAME_STUDENT': '#8000ff',
            'EMAIL': '#2b7ff6',
            'USERNAME': '#2adddd',
            'ID_NUM': '#80ffb4',
            'PHONE_NUM': 'd4dd80',
            'URL_PERSONAL': '#ff8042',
            'STREET_ADDRESS': '#ff0000'
         }


def visualize(full_text,offset_mapping,labels):
    
    ents = []
    for offset,lab in zip(offset_mapping,labels):
        ents.append({
                        'start': int(offset[0]), 
                         'end': int(offset[1]), 
                         'label': str(lab.split('-')[1]) #+ ' - ' + str(row['discourse_effectiveness'])
                    })

    doc2 = {
        "text": full_text,
        "ents": ents,
#         "title": "idx"
    }

    options = {"ents": list(colors.keys()), "colors": colors}
    displacy.render(doc2, style="ent", options=options, manual=True, jupyter=True)

# %% [markdown]
# # Params

# %%
data_path = Path(r"/database/kaggle/PII/data")
os.listdir(data_path)
# Out:
# ['train.json',
#  'mpware_mixtral8x7b_v1.1-no-i-username.json',
#  'pii_dataset_fixed.csv',
#  'mixtral-8x7b-v1.json',
#  '.~lock.lecture2.pptx#',
#  'Fake_data_1850_218.json',
#  'test.json',
#  'archive.zip',
#  'archive',
#  'pii-masking-200k.csv',
#  'sample_submission.csv',
#  'mpware_mixtral8x7b_v1.1.json']

# %%
CHECKPOINT_PATH = Path(r"/database/kaggle/PII/checkpoint")

# %%
os.listdir(CHECKPOINT_PATH/"fold_msk_5_seed_42"/'deberta-v3-large')
# Out:
# ['2024-04-04--dv3l_cp_nbrod_add05_rep_05_v1',
#  '2024-04-06--dv3l_cp_nbrod_add00_rep_00_v1',
#  '2024-02-04--vsub1',
#  '2024-04-03--dv3l_cp_nbrod_add05_rep_05_v1']

# %% [markdown]
# # Data

# %%
FOLD_NAME = "fold_msk_5_seed_42"
model_name = "deberta-v3-large" 
exp_name = "2024-02-04--vsub1"
folder = str(CHECKPOINT_PATH/Path(fr'{FOLD_NAME}/{model_name}/{exp_name}')) 
os.listdir(folder)
# Out:
# ['fold_3 _epoch_5 _step_5856 _valid_loss_0.0071 _f5_micro_0.9985 _train_loss_0.0006.pth',
#  'tokenizer',
#  'params.json',
#  'oof_blend.csv',
#  'fold_2 _epoch_9 _step_7331 _valid_loss_0.0072 _f5_micro_0.9984 _train_loss_0.0001.pth',
#  'fold_1 _epoch_5 _step_4397 _valid_loss_0.0060 _f5_micro_0.9982 _train_loss_0.0012.pth',
#  'fold_4 _epoch_5 _step_7322 _valid_loss_0.0051 _f5_micro_0.9978 _train_loss_0.0011.pth',
#  'config.pth',
#  'fold_0 _epoch_8 _step_7331 _valid_loss_0.0080 _f5_micro_0.9981 _train_loss_0.0004.pth',
#  'oof.csv',
#  'tokenizer.zip']

# %%
df = pd.read_csv(folder+'/oof.csv')
df.shape
# Out:
# (6807, 23)

# %%
df_blend = pd.read_csv(folder+'/oof_blend.csv')
df_blend.shape
# Out:
# (6807, 23)

# %%
df1 = df.copy()

# %%
df = df.merge(df1,how='left',on='document',suffixes=('','_m2'))

# %%
df = df.merge(df_blend,how='left',on='document',suffixes=('','_mbl'))

# %%
df.head(2)
# Out:
#    document                                          full_text                                             tokens                                trailing_whitespace                                             labels  NAME_STUDENT  EMAIL  USERNAME  ID_NUM  PHONE_NUM  URL_PERSONAL  STREET_ADDRESS  fold_msk_5_seed_42  NAME_STUDENT_s  f5_micro  URL_PERSONAL_s  ID_NUM_s  EMAIL_s  USERNAME_s  PHONE_NUM_s  STREET_ADDRESS_s                                              label  \
# 0         7  Design Thinking for innovation reflexion-Avril...  ['Design', 'Thinking', 'for', 'innovation', 'r...  [True, True, True, True, False, False, True, F...  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...             1      0         0       0          0             0               0                   3          0.9811    0.9811             NaN       NaN      NaN         NaN          NaN               NaN  ['O', 'O', 'O', 'O', 'O', 'O', 'B-NAME_STUDENT...
# 1        10  Diego Estrada\n\nDesign Thinking Assignment\n\...  ['Diego', 'Estrada', '\n\n', 'Design', 'Thinki...  [True, False, False, True, True, False, False,...  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...             1      0         0       0          0             0               0                   4          1.0000    1.0000             NaN       NaN      NaN         NaN          NaN               NaN  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...
#
#                                                score                                       full_text_m2                                          tokens_m2                             trailing_whitespace_m2                                          labels_m2  NAME_STUDENT_m2  EMAIL_m2  USERNAME_m2  ID_NUM_m2  PHONE_NUM_m2  URL_PERSONAL_m2  STREET_ADDRESS_m2  fold_msk_5_seed_42_m2  NAME_STUDENT_s_m2  f5_micro_m2  URL_PERSONAL_s_m2  EMAIL_s_m2  ID_NUM_s_m2  USERNAME_s_m2  PHONE_NUM_s_m2  \
# 0  [0.9989989399909973, 0.9996565580368042, 0.999...  Design Thinking for innovation reflexion-Avril...  ['Design', 'Thinking', 'for', 'innovation', 'r...  [True, True, True, True, False, False, True, F...  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                1         0            0          0             0                0                  0                      3             1.0000       1.0000                NaN         NaN          NaN            NaN             NaN
# 1  [0.999984622001648, 0.9999905824661255, 0.9999...  Diego Estrada\n\nDesign Thinking Assignment\n\...  ['Diego', 'Estrada', '\n\n', 'Design', 'Thinki...  [True, False, False, True, True, False, False,...  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...                1         0            0          0             0                0                  0                      4             1.0000       1.0000                NaN         NaN          NaN            NaN             NaN
#
#    STREET_ADDRESS_s_m2                                           label_m2                                           score_m2  full_text_size                                      full_text_mbl                                         tokens_mbl                            trailing_whitespace_mbl                                         labels_mbl  NAME_STUDENT_mbl  EMAIL_mbl  USERNAME_mbl  ID_NUM_mbl  PHONE_NUM_mbl  URL_PERSONAL_mbl  STREET_ADDRESS_mbl  fold_msk_5_seed_42_mbl  NAME_STUDENT_s_mbl  \
# 0                  NaN  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...  [0.9999632835388184, 0.9999855756759644, 0.999...            3709  Design Thinking for innovation reflexion-Avril...  ['Design', 'Thinking', 'for', 'innovation', 'r...  [True, True, True, True, False, False, True, F...  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...                 1          0             0           0              0                 0                   0                       3              0.9811
# 1                  NaN  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...  [0.9999055862426758, 0.9999181032180786, 0.999...            2915  Diego Estrada\n\nDesign Thinking Assignment\n\...  ['Diego', 'Estrada', '\n\n', 'Design', 'Thinki...  [True, False, False, True, True, False, False,...  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...                 1          0             0           0              0                 0                   0                       4              1.0000
#
#    f5_micro_mbl  URL_PERSONAL_s_mbl  ID_NUM_s_mbl  EMAIL_s_mbl  USERNAME_s_mbl  PHONE_NUM_s_mbl  STREET_ADDRESS_s_mbl                                          label_mbl                                          score_mbl
# 0        0.9811                 NaN           NaN          NaN             NaN              NaN                   NaN  ['O', 'O', 'O', 'O', 'O', 'O', 'B-NAME_STUDENT...  [0.9989393353462219, 0.9996445178985596, 0.999...
# 1        1.0000                 NaN           NaN          NaN             NaN              NaN                   NaN  ['B-NAME_STUDENT', 'I-NAME_STUDENT', 'O', 'O',...  [0.9999833106994629, 0.9999881982803345, 0.999...

# %%
df['full_text_size'] = df['full_text'].str.len()

# %%
LABELS = ['NAME_STUDENT','EMAIL','USERNAME','ID_NUM', 'PHONE_NUM','URL_PERSONAL','STREET_ADDRESS']

# %%
df[df['f5_micro'].isna()][LABELS].sum()
# Out:
# NAME_STUDENT      0
# EMAIL             0
# USERNAME          0
# ID_NUM            0
# PHONE_NUM         0
# URL_PERSONAL      0
# STREET_ADDRESS    0
# dtype: int64

# %%
df[df['f5_micro'].notna()][LABELS+[x+'_s' for x in LABELS]+['full_text_size']].corr()
# Out:
#                   NAME_STUDENT   EMAIL  USERNAME  ID_NUM  PHONE_NUM  URL_PERSONAL  STREET_ADDRESS  NAME_STUDENT_s  EMAIL_s  USERNAME_s  ID_NUM_s  PHONE_NUM_s  URL_PERSONAL_s  STREET_ADDRESS_s  full_text_size
# NAME_STUDENT            1.0000  0.0259   -0.0542  0.0244    -0.0009       -0.1937         -0.0246          0.9691   0.2254      0.0328    0.5615       0.0913          0.1566            0.5000         -0.0386
# EMAIL                   0.0259  1.0000    0.0830  0.0119     0.3015        0.0886         -0.0059          0.0625   1.0000      0.1771    0.1299       0.4167          0.0092           -1.0000          0.0176
# USERNAME               -0.0542  0.0830    1.0000 -0.0111    -0.0038       -0.0167         -0.0027          0.0212   0.0577      1.0000       NaN          NaN             NaN               NaN         -0.0171
# ID_NUM                  0.0244  0.0119   -0.0111  1.0000    -0.0099       -0.0433         -0.0070          0.0664   0.0577     -0.0892    0.8434      -0.7303             NaN               NaN         -0.1186
# PHONE_NUM              -0.0009  0.3015   -0.0038 -0.0099     1.0000        0.0460          0.3520          0.0260  -0.2770     -0.0622       NaN       1.0000         -0.0406           -0.5000         -0.0090
# URL_PERSONAL           -0.1937  0.0886   -0.0167 -0.0433     0.0460        1.0000          0.0756          0.0271  -0.1845     -0.0622   -0.2223      -0.0913          0.9782            0.5000          0.0649
# STREET_ADDRESS         -0.0246 -0.0059   -0.0027 -0.0070     0.3520        0.0756          1.0000         -0.0347  -0.6928         NaN       NaN       0.3536          0.0719            1.0000          0.0091
# NAME_STUDENT_s          0.9691  0.0625    0.0212  0.0664     0.0260        0.0271         -0.0347          1.0000  -0.0634      0.1968    0.4112       0.6124          0.0526               NaN         -0.0475
# EMAIL_s                 0.2254  1.0000    0.0577  0.0577    -0.2770       -0.1845         -0.6928         -0.0634   1.0000         NaN       NaN      -0.2500         -0.2648           -1.0000         -0.0625
# USERNAME_s              0.0328  0.1771    1.0000 -0.0892    -0.0622       -0.0622             NaN          0.1968      NaN      1.0000       NaN          NaN             NaN               NaN         -0.1093
# ID_NUM_s                0.5615  0.1299       NaN  0.8434        NaN       -0.2223             NaN          0.4112      NaN         NaN    1.0000          NaN             NaN               NaN         -0.5883
# PHONE_NUM_s             0.0913  0.4167       NaN -0.7303     1.0000       -0.0913          0.3536          0.6124  -0.2500         NaN       NaN       1.0000         -0.5000               NaN         -0.4120
# URL_PERSONAL_s          0.1566  0.0092       NaN     NaN    -0.0406        0.9782          0.0719          0.0526  -0.2648         NaN       NaN      -0.5000          1.0000            1.0000          0.0253
# STREET_ADDRESS_s        0.5000 -1.0000       NaN     NaN    -0.5000        0.5000          1.0000             NaN  -1.0000         NaN       NaN          NaN          1.0000            1.0000         -0.6135
# full_text_size         -0.0386  0.0176   -0.0171 -0.1186    -0.0090        0.0649          0.0091         -0.0475  -0.0625     -0.1093   -0.5883      -0.4120          0.0253           -0.6135          1.0000

# %%
idx = random.choice(df[(df.PHONE_NUM_s<1)].index)
# idx = dfold[dfold.document==doc].index[0]
# Example usage:
# idx = "uzvemcjmik"
full_text_ds = df.iloc[idx]['full_text']
tokens_ds = eval(df.iloc[idx]['tokens'])
labels_ds = eval(df.iloc[idx]['labels'])
labels = eval(df.iloc[idx]['label'])
scores = eval(df.iloc[idx]['score'])
idx,df.iloc[idx]['document']
# Out:
# (374, 6537)

# %%
def visualize_preds(df,mask):
    
    idx = random.choice(df[mask].index)
    full_text_ds = df.iloc[idx]['full_text']
    tokens_ds = eval(df.iloc[idx]['tokens'])
    labels_ds = eval(df.iloc[idx]['labels'])
    labels = eval(df.iloc[idx]['label'])
    scores = eval(df.iloc[idx]['score'])
    
    labels2 = eval(df.iloc[idx]['label_m2'])
    scores2 = eval(df.iloc[idx]['score_m2'])
    
    labelsbl = eval(df.iloc[idx]['label_mbl'])
    scoresbl = eval(df.iloc[idx]['score_mbl'])
    
    
    offset_mapping = get_offset_mapping(full_text_ds, tokens_ds)
    offset_mapping_ = [x for (x,y) in zip(offset_mapping,labels_ds) if y!="O"]
    labels_ = [x for x in labels_ds if x!="O"]
    
    print(" -------------------------------------- GT ---------------------------------------")
    print(" --------------------------------------   ---------------------------------------")
    visualize(full_text_ds,offset_mapping_,labels_)
    
    print(" --------------------------------------   ---------------------------------------\n")
    
    print(" -------------------------------------- Pred ---------------------------------------")
    print(" --------------------------------------   ---------------------------------------\n")
    offset_mapping = get_offset_mapping(full_text_ds, tokens_ds)
    offset_mapping_ = [x for (x,y,s) in zip(offset_mapping,labels,scores) if y!="O" and s>0.15]
    labels_ = [x for (x,s) in zip(labels,scores) if x!="O" and s>0.15]
    visualize(full_text_ds,offset_mapping_,labels_)
    
    
    print(" -------------------------------------- Pred m2---------------------------------------")
    print(" --------------------------------------   ---------------------------------------\n")
    offset_mapping = get_offset_mapping(full_text_ds, tokens_ds)
    offset_mapping_ = [x for (x,y,s) in zip(offset_mapping,labels2,scores2) if y!="O" and s>0.15]
    labels_ = [x for (x,s) in zip(labels2,scores2) if x!="O" and s>0.15]
    visualize(full_text_ds,offset_mapping_,labels_)
    
    
    
    print(" -------------------------------------- Pred blend---------------------------------------")
    print(" --------------------------------------   ---------------------------------------\n")
    offset_mapping = get_offset_mapping(full_text_ds, tokens_ds)
    offset_mapping_ = [x for (x,y,s) in zip(offset_mapping,labelsbl,scoresbl) if y!="O" and s>0.15]
    labels_ = [x for (x,s) in zip(labelsbl,scoresbl) if x!="O" and s>0.15]
    visualize(full_text_ds,offset_mapping_,labels_)

# %%
# doc test 9674

# %%
df[(df.f5_micro!=df.f5_micro_m2)][LABELS].sum()
# Out:
# NAME_STUDENT      105
# EMAIL               4
# USERNAME            0
# ID_NUM              8
# PHONE_NUM           1
# URL_PERSONAL       11
# STREET_ADDRESS      1
# dtype: int64

# %%
visualize_preds(df,((df.f5_micro!=df.f5_micro_m2) & (df.f5_micro_m2.notna())))
# Out:
#  -------------------------------------- GT ---------------------------------------
#  --------------------------------------   ---------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>On Design Thinking: A Reflection On Reworking A Novel<br><br>A year ago I began working on a novel with the idea that all I needed was a cast of characters, a<br><br>world and a plot that went from A to B. I could not have been more wrong. Around three-fourths of<br><br>the way through the novel, I found myself writing without direction, caught in the nitty-gritties of<br><br>detail, worldbuilding and characters; unable to extract the story and push it in the direction that I<br><br>wanted it to go in. Towards the very end of the writing, the story had spiraled out of control, into<br><br>something that had too many motifs and themes to be truly thoughtful. It was directionless and<br><br>frequently contradictory – even incoherent, in places, with incomplete character arcs that ended in<br><br>the classic rookie writer’s problem: they simply disappeared off the map altogether.<br><br>This is, perhaps, an unorthodox example to pick for a design thinking project. But as I listened to the<br><br>lectures on design thinking, I was forcibly struck by the similarities between the description of the<br><br>process – what is, what if, what wows, what works – and the ways in which this process parallels the<br><br>creation of a novel. Early on in the lectures, Diaz picked apart the concept of the Moses<br><br>myth of creativity, i.e. that creativity resides purely in genius and is not something which can be<br><br>cultivated or organized. This was when I realized that all along I’d been treating the novel as a<br><br>mysterious entity which could only be produced through genius, rather than a project which could<br><br>be managed systematically – which, dare I say, could even be created by using design thinking<br><br>principles.<br><br>Selection &amp; Application<br><br>So I went back to the drawing board and decided to treat the novel as a project, rather than a<br><br>mysterious entity which would spring fully formed from my mind. I selected the Visualization tool<br><br>we’d explored over the five weeks for this and began to rebuild my novel from the ground up. The<br><br>visualization tool felt like the appropriate choice in that it is a useful way in which to place ideas<br><br>which are not necessarily easily verbalized on paper – which gives it a tangible presence that makes<br><br>it easier to discern unconscious and latent patterns, needs and desires that would not have been<br><br>immediately evident otherwise. The intangible nature of themes and motifs were best matched to<br><br>the visualization tool which enables the formulation of the intangible in a way that makes it easier to<br><br>grasp and think about. It was also an excellent way of escaping from the tendency to return to<br><br>outlines and other collected material – words, in other words – and to force me to take a step back<br><br>and think outside the box – outside my preconceived notions and ideas – when examining what I<br><br>wanted to do with my novel.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>Rather than turn this process over to a group of people, however, I used the visualization tool in a<br><br>more personal and auto-ethnographical sense, to express the various concepts, themes and motifs –<br><br>occasionally even moments – I had been exploring in my novel. I did this by creating several collage-<br><br>cum-moodboard of images and fragments of thoughts, phrases and ideas that were both academic<br><br>and literary or poetical which I had been both unconsciously and consciously examining – which<br><br>struck a chord with me whenever I thought about my novel’s plot, various characters and themes. I<br><br>then laid it out and tried to trace the patterns and themes which emerged, to be more conscious of<br><br>what I had been working with and to see how they all fit together within the context of my novel.<br><br>Insights &amp; Approach<br><br>By thinking conceptually, rather than falling back on the standard formats of novel outlining, I began<br><br>to notice certain themes and ideas which were connecting characters who had existed very<br><br>separately on the page before. Where they once crossed each other without ever interacting or even<br><br>appearing linked except for the bare necessities of plot, I noticed certain ideas which kept cropping<br><br>up and recurring, visually framed, across these different characters. They weren’t necessarily similar<br><br>themes so much as motifs; symbolic elements which I had failed to be conscious of while writing,<br><br>which had led to the characters meandering all over the page without necessarily going anywhere.<br><br>As a tool, the visualization tool forced me to quite literally build from scratch – to stay away from<br><br>falling back on ‘safe’ and ‘known’ things like the plot outline and the lists and sheets I’d built up over<br><br>the last year – and by doing so, it formed a new framework of thinking about the novel. I had a<br><br>‘thesis statement’, now, for the piece: one unifying theme and question I could come back to when I<br><br>worked on the various elements of the story. It was being able to reframe these verbal ideas I’d had<br><br>and transferring them into another medium, one which was more conceptual – like a Rorschach, as<br><br>it was called in one of the video lectures – that made it easier to trace the more subconscious<br><br>connections – or the possible subconscious connections at play – and to unify them in patterns and<br><br>ideas that could form a thesis statement for my novel.<br><br>I’d used this tool a few times before when writing stories, but doing it in light of thinking of it as a<br><br>design thinking tool helped me to be a lot more conscious of the process and to treat this less as a<br><br>fun or relaxing activity and more as a learning experience. These images and fragments of concepts<br><br>weren’t just images but tools which could yield insights into my own unconscious desires and needs<br><br>while writing this novel – a way of understanding what I’d wanted to explore and how to be<br><br>conscious about it, instead of going about it vaguely as I did before.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; lin
#  --------------------------------------   ---------------------------------------
#
#  -------------------------------------- Pred ---------------------------------------
#  --------------------------------------   ---------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>On Design Thinking: A Reflection On Reworking A Novel<br><br>A year ago I began working on a novel with the idea that all I needed was a cast of characters, a<br><br>world and a plot that went from A to B. I could not have been more wrong. Around three-fourths of<br><br>the way through the novel, I found myself writing without direction, caught in the nitty-gritties of<br><br>detail, worldbuilding and characters; unable to extract the story and push it in the direction that I<br><br>wanted it to go in. Towards the very end of the writing, the story had spiraled out of control, into<br><br>something that had too many motifs and themes to be truly thoughtful. It was directionless and<br><br>frequently contradictory – even incoherent, in places, with incomplete character arcs that ended in<br><br>the classic rookie writer’s problem: they simply disappeared off the map altogether.<br><br>This is, perhaps, an unorthodox example to pick for a design thinking project. But as I listened to the<br><br>lectures on design thinking, I was forcibly struck by the similarities between the description of the<br><br>process – what is, what if, what wows, what works – and the ways in which this process parallels the<br><br>creation of a novel. Early on in the lectures, Diaz picked apart the concept of the Moses<br><br>myth of creativity, i.e. that creativity resides purely in genius and is not something which can be<br><br>cultivated or organized. This was when I realized that all along I’d been treating the novel as a<br><br>mysterious entity which could only be produced through genius, rather than a project which could<br><br>be managed systematically – which, dare I say, could even be created by using design thinking<br><br>principles.<br><br>Selection &amp; Application<br><br>So I went back to the drawing board and decided to treat the novel as a project, rather than a<br><br>mysterious entity which would spring fully formed from my mind. I selected the Visualization tool<br><br>we’d explored over the five weeks for this and began to rebuild my novel from the ground up. The<br><br>visualization tool felt like the appropriate choice in that it is a useful way in which to place ideas<br><br>which are not necessarily easily verbalized on paper – which gives it a tangible presence that makes<br><br>it easier to discern unconscious and latent patterns, needs and desires that would not have been<br><br>immediately evident otherwise. The intangible nature of themes and motifs were best matched to<br><br>the visualization tool which enables the formulation of the intangible in a way that makes it easier to<br><br>grasp and think about. It was also an excellent way of escaping from the tendency to return to<br><br>outlines and other collected material – words, in other words – and to force me to take a step back<br><br>and think outside the box – outside my preconceived notions and ideas – when examining what I<br><br>wanted to do with my novel.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>Rather than turn this process over to a group of people, however, I used the visualization tool in a<br><br>more personal and auto-ethnographical sense, to express the various concepts, themes and motifs –<br><br>occasionally even moments – I had been exploring in my novel. I did this by creating several collage-<br><br>cum-moodboard of images and fragments of thoughts, phrases and ideas that were both academic<br><br>and literary or poetical which I had been both unconsciously and consciously examining – which<br><br>struck a chord with me whenever I thought about my novel’s plot, various characters and themes. I<br><br>then laid it out and tried to trace the patterns and themes which emerged, to be more conscious of<br><br>what I had been working with and to see how they all fit together within the context of my novel.<br><br>Insights &amp; Approach<br><br>By thinking conceptually, rather than falling back on the standard formats of novel outlining, I began<br><br>to notice certain themes and ideas which were connecting characters who had existed very<br><br>separately on the page before. Where they once crossed each other without ever interacting or even<br><br>appearing linked except for the bare necessities of plot, I noticed certain ideas which kept cropping<br><br>up and recurring, visually framed, across these different characters. They weren’t necessarily similar<br><br>themes so much as motifs; symbolic elements which I had failed to be conscious of while writing,<br><br>which had led to the characters meandering all over the page without necessarily going anywhere.<br><br>As a tool, the visualization tool forced me to quite literally build from scratch – to stay away from<br><br>falling back on ‘safe’ and ‘known’ things like the plot outline and the lists and sheets I’d built up over<br><br>the last year – and by doing so, it formed a new framework of thinking about the novel. I had a<br><br>‘thesis statement’, now, for the piece: one unifying theme and question I could come back to when I<br><br>worked on the various elements of the story. It was being able to reframe these verbal ideas I’d had<br><br>and transferring them into another medium, one which was more conceptual – like a Rorschach, as<br><br>it was called in one of the video lectures – that made it easier to trace the more subconscious<br><br>connections – or the possible subconscious connections at play – and to unify them in patterns and<br><br>ideas that could form a thesis statement for my novel.<br><br>I’d used this tool a few times before when writing stories, but doing it in light of thinking of it as a<br><br>design thinking tool helped me to be a lot more conscious of the process and to treat this less as a<br><br>fun or relaxing activity and more as a learning experience. These images and fragments of concepts<br><br>weren’t just images but tools which could yield insights into my own unconscious desires and needs<br><br>while writing this novel – a way of understanding what I’d wanted to explore and how to be<br><br>conscious about it, instead of going about it vaguely as I did before.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; lin
#  -------------------------------------- Pred m2---------------------------------------
#  --------------------------------------   ---------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>On Design Thinking: A Reflection On Reworking A Novel<br><br>A year ago I began working on a novel with the idea that all I needed was a cast of characters, a<br><br>world and a plot that went from A to B. I could not have been more wrong. Around three-fourths of<br><br>the way through the novel, I found myself writing without direction, caught in the nitty-gritties of<br><br>detail, worldbuilding and characters; unable to extract the story and push it in the direction that I<br><br>wanted it to go in. Towards the very end of the writing, the story had spiraled out of control, into<br><br>something that had too many motifs and themes to be truly thoughtful. It was directionless and<br><br>frequently contradictory – even incoherent, in places, with incomplete character arcs that ended in<br><br>the classic rookie writer’s problem: they simply disappeared off the map altogether.<br><br>This is, perhaps, an unorthodox example to pick for a design thinking project. But as I listened to the<br><br>lectures on design thinking, I was forcibly struck by the similarities between the description of the<br><br>process – what is, what if, what wows, what works – and the ways in which this process parallels the<br><br>creation of a novel. Early on in the lectures,
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diaz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#  picked apart the concept of the Moses<br><br>myth of creativity, i.e. that creativity resides purely in genius and is not something which can be<br><br>cultivated or organized. This was when I realized that all along I’d been treating the novel as a<br><br>mysterious entity which could only be produced through genius, rather than a project which could<br><br>be managed systematically – which, dare I say, could even be created by using design thinking<br><br>principles.<br><br>Selection &amp; Application<br><br>So I went back to the drawing board and decided to treat the novel as a project, rather than a<br><br>mysterious entity which would spring fully formed from my mind. I selected the Visualization tool<br><br>we’d explored over the five weeks for this and began to rebuild my novel from the ground up. The<br><br>visualization tool felt like the appropriate choice in that it is a useful way in which to place ideas<br><br>which are not necessarily easily verbalized on paper – which gives it a tangible presence that makes<br><br>it easier to discern unconscious and latent patterns, needs and desires that would not have been<br><br>immediately evident otherwise. The intangible nature of themes and motifs were best matched to<br><br>the visualization tool which enables the formulation of the intangible in a way that makes it easier to<br><br>grasp and think about. It was also an excellent way of escaping from the tendency to return to<br><br>outlines and other collected material – words, in other words – and to force me to take a step back<br><br>and think outside the box – outside my preconceived notions and ideas – when examining what I<br><br>wanted to do with my novel.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>Rather than turn this process over to a group of people, however, I used the visualization tool in a<br><br>more personal and auto-ethnographical sense, to express the various concepts, themes and motifs –<br><br>occasionally even moments – I had been exploring in my novel. I did this by creating several collage-<br><br>cum-moodboard of images and fragments of thoughts, phrases and ideas that were both academic<br><br>and literary or poetical which I had been both unconsciously and consciously examining – which<br><br>struck a chord with me whenever I thought about my novel’s plot, various characters and themes. I<br><br>then laid it out and tried to trace the patterns and themes which emerged, to be more conscious of<br><br>what I had been working with and to see how they all fit together within the context of my novel.<br><br>Insights &amp; Approach<br><br>By thinking conceptually, rather than falling back on the standard formats of novel outlining, I began<br><br>to notice certain themes and ideas which were connecting characters who had existed very<br><br>separately on the page before. Where they once crossed each other without ever interacting or even<br><br>appearing linked except for the bare necessities of plot, I noticed certain ideas which kept cropping<br><br>up and recurring, visually framed, across these different characters. They weren’t necessarily similar<br><br>themes so much as motifs; symbolic elements which I had failed to be conscious of while writing,<br><br>which had led to the characters meandering all over the page without necessarily going anywhere.<br><br>As a tool, the visualization tool forced me to quite literally build from scratch – to stay away from<br><br>falling back on ‘safe’ and ‘known’ things like the plot outline and the lists and sheets I’d built up over<br><br>the last year – and by doing so, it formed a new framework of thinking about the novel. I had a<br><br>‘thesis statement’, now, for the piece: one unifying theme and question I could come back to when I<br><br>worked on the various elements of the story. It was being able to reframe these verbal ideas I’d had<br><br>and transferring them into another medium, one which was more conceptual – like a Rorschach, as<br><br>it was called in one of the video lectures – that made it easier to trace the more subconscious<br><br>connections – or the possible subconscious connections at play – and to unify them in patterns and<br><br>ideas that could form a thesis statement for my novel.<br><br>I’d used this tool a few times before when writing stories, but doing it in light of thinking of it as a<br><br>design thinking tool helped me to be a lot more conscious of the process and to treat this less as a<br><br>fun or relaxing activity and more as a learning experience. These images and fragments of concepts<br><br>weren’t just images but tools which could yield insights into my own unconscious desires and needs<br><br>while writing this novel – a way of understanding what I’d wanted to explore and how to be<br><br>conscious about it, instead of going about it vaguely as I did before.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-heig
#  -------------------------------------- Pred blend---------------------------------------
#  --------------------------------------   ---------------------------------------
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>On Design Thinking: A Reflection On Reworking A Novel<br><br>A year ago I began working on a novel with the idea that all I needed was a cast of characters, a<br><br>world and a plot that went from A to B. I could not have been more wrong. Around three-fourths of<br><br>the way through the novel, I found myself writing without direction, caught in the nitty-gritties of<br><br>detail, worldbuilding and characters; unable to extract the story and push it in the direction that I<br><br>wanted it to go in. Towards the very end of the writing, the story had spiraled out of control, into<br><br>something that had too many motifs and themes to be truly thoughtful. It was directionless and<br><br>frequently contradictory – even incoherent, in places, with incomplete character arcs that ended in<br><br>the classic rookie writer’s problem: they simply disappeared off the map altogether.<br><br>This is, perhaps, an unorthodox example to pick for a design thinking project. But as I listened to the<br><br>lectures on design thinking, I was forcibly struck by the similarities between the description of the<br><br>process – what is, what if, what wows, what works – and the ways in which this process parallels the<br><br>creation of a novel. Early on in the lectures,
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Diaz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#  picked apart the concept of the Moses<br><br>myth of creativity, i.e. that creativity resides purely in genius and is not something which can be<br><br>cultivated or organized. This was when I realized that all along I’d been treating the novel as a<br><br>mysterious entity which could only be produced through genius, rather than a project which could<br><br>be managed systematically – which, dare I say, could even be created by using design thinking<br><br>principles.<br><br>Selection &amp; Application<br><br>So I went back to the drawing board and decided to treat the novel as a project, rather than a<br><br>mysterious entity which would spring fully formed from my mind. I selected the Visualization tool<br><br>we’d explored over the five weeks for this and began to rebuild my novel from the ground up. The<br><br>visualization tool felt like the appropriate choice in that it is a useful way in which to place ideas<br><br>which are not necessarily easily verbalized on paper – which gives it a tangible presence that makes<br><br>it easier to discern unconscious and latent patterns, needs and desires that would not have been<br><br>immediately evident otherwise. The intangible nature of themes and motifs were best matched to<br><br>the visualization tool which enables the formulation of the intangible in a way that makes it easier to<br><br>grasp and think about. It was also an excellent way of escaping from the tendency to return to<br><br>outlines and other collected material – words, in other words – and to force me to take a step back<br><br>and think outside the box – outside my preconceived notions and ideas – when examining what I<br><br>wanted to do with my novel.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME_STUDENT</span>
# </mark>
# <br><br>29/10/2016<br><br>Rather than turn this process over to a group of people, however, I used the visualization tool in a<br><br>more personal and auto-ethnographical sense, to express the various concepts, themes and motifs –<br><br>occasionally even moments – I had been exploring in my novel. I did this by creating several collage-<br><br>cum-moodboard of images and fragments of thoughts, phrases and ideas that were both academic<br><br>and literary or poetical which I had been both unconsciously and consciously examining – which<br><br>struck a chord with me whenever I thought about my novel’s plot, various characters and themes. I<br><br>then laid it out and tried to trace the patterns and themes which emerged, to be more conscious of<br><br>what I had been working with and to see how they all fit together within the context of my novel.<br><br>Insights &amp; Approach<br><br>By thinking conceptually, rather than falling back on the standard formats of novel outlining, I began<br><br>to notice certain themes and ideas which were connecting characters who had existed very<br><br>separately on the page before. Where they once crossed each other without ever interacting or even<br><br>appearing linked except for the bare necessities of plot, I noticed certain ideas which kept cropping<br><br>up and recurring, visually framed, across these different characters. They weren’t necessarily similar<br><br>themes so much as motifs; symbolic elements which I had failed to be conscious of while writing,<br><br>which had led to the characters meandering all over the page without necessarily going anywhere.<br><br>As a tool, the visualization tool forced me to quite literally build from scratch – to stay away from<br><br>falling back on ‘safe’ and ‘known’ things like the plot outline and the lists and sheets I’d built up over<br><br>the last year – and by doing so, it formed a new framework of thinking about the novel. I had a<br><br>‘thesis statement’, now, for the piece: one unifying theme and question I could come back to when I<br><br>worked on the various elements of the story. It was being able to reframe these verbal ideas I’d had<br><br>and transferring them into another medium, one which was more conceptual – like a Rorschach, as<br><br>it was called in one of the video lectures – that made it easier to trace the more subconscious<br><br>connections – or the possible subconscious connections at play – and to unify them in patterns and<br><br>ideas that could form a thesis statement for my novel.<br><br>I’d used this tool a few times before when writing stories, but doing it in light of thinking of it as a<br><br>design thinking tool helped me to be a lot more conscious of the process and to treat this less as a<br><br>fun or relaxing activity and more as a learning experience. These images and fragments of concepts<br><br>weren’t just images but tools which could yield insights into my own unconscious desires and needs<br><br>while writing this novel – a way of understanding what I’d wanted to explore and how to be<br><br>conscious about it, instead of going about it vaguely as I did before.<br><br>
# <mark class="entity" style="background: #8000ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dawn
#     <span style="font-size: 0.8em; font-weight: bold; line-heig
